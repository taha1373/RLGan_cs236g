# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/courses/Generative\ Adversial\ Models_CS236g/RLGan_cs236g/
# !ls
# Out:
# /content/drive/My Drive/courses/Generative Adversial Models_CS236g/RLGan_cs236g
#  console.ipynb	  Losses.py   __pycache__   VAE_c.py		 VAE_trainer.py
#  gan_main.py	  MNIST       README.md     VAE_jupyter.ipynb	 visualizer.py
#  gan.py		  models      spectral.py   VAE_main.py
#  gan_trainer.py   papers      utils.py	   'VAE_train copy.py'

# %%
# !python VAE_main.py --numEpochs 10
# Out:
# Epoch 0
# 100% 59/59 [00:04<00:00, 11.87it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 1
# 100% 59/59 [00:04<00:00, 12.15it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 2
# 100% 59/59 [00:04<00:00, 12.52it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 3
# 100% 59/59 [00:04<00:00, 12.29it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 4
# 100% 59/59 [00:04<00:00, 12.41it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 5
# 100% 59/59 [00:04<00:00, 12.00it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 6
# 100% 59/59 [00:04<00:00, 12.14it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 7
# 100% 59/59 [00:04<00:00, 12.06it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 8
# 100% 59/59 [00:04<00:00, 12.15it/s]
# <Figure size 640x480 with 2 Axes>
# Epoch 9
# 100% 59/59 [00:04<00:00, 12.15it/s]
# <Figure size 640x480 with 2 Axes>

# %%
from VAE_c import VAE
vae = VAE()

# %%
vae.state_dict
# Out:
# <bound method Module.state_dict of VAE(
#   (encode): Encoder(
#     (disc): Sequential(
#       (0): Sequential(
#         (0): Conv2d(1, 16, kernel_size=(4, 4), stride=(2, 2))
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2))
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       )
#     )
#   )
#   (decode): Decoder(
#     (gen): Sequential(
#       (0): Sequential(
#         (0): ConvTranspose2d(32, 256, kernel_size=(3, 3), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (3): Sequential(
#         (0): ConvTranspose2d(64, 1, kernel_size=(4, 4), stride=(2, 2))
#         (1): Sigmoid()
#       )
#     )
#   )
# )>

# %%
vae.load_state_dict(torch.load(PATH))

# %%
from VAE_train import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-33e991239e22> in <module>()
# ----> 1 from VAE_train import *
#
# ModuleNotFoundError: No module named 'VAE_train'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/ed/0e/5c61eedde9f6c87713e89d794f01e378cfd9565847d4576fa627d758c554/GPUtil-1.4.0.tar.gz
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp37-none-any.whl size=7411 sha256=7e52ed8040589ba8a37edbdaedbf2092ff35828dec32db2f107a7068e2a4fbee
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.7/dist-packages (0.5.1)

# %%
GPU.getGPUs()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f2a1e902938> in <module>()
# ----> 1 GPU.getGPUs()
#
# NameError: name 'GPU' is not defined

# %%
main('cuda')
# Out:
# Epoch 0
# 100%|██████████| 59/59 [00:04<00:00, 13.15it/s]
# Epoch 1
# 100%|██████████| 59/59 [00:04<00:00, 13.01it/s]
# Epoch 2
# 100%|██████████| 59/59 [00:04<00:00, 13.39it/s]
# Epoch 3
# 100%|██████████| 59/59 [00:04<00:00, 13.22it/s]
# Epoch 4
# 100%|██████████| 59/59 [00:04<00:00, 13.27it/s]
# Epoch 5
# 100%|██████████| 59/59 [00:04<00:00, 13.14it/s]
# Epoch 6
# 100%|██████████| 59/59 [00:04<00:00, 13.22it/s]
# Epoch 7
# 100%|██████████| 59/59 [00:04<00:00, 12.93it/s]
# Epoch 8
# 100%|██████████| 59/59 [00:04<00:00, 13.21it/s]
# Epoch 9
# 100%|██████████| 59/59 [00:04<00:00, 12.97it/s]
