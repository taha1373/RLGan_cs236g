# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/courses/Generative\ Adversial\ Models_CS236g/RLGan_cs236g/
# !ls
# Out:
# /content/drive/My Drive/courses/Generative Adversial Models_CS236g/RLGan_cs236g
# AE_main.py		       gan_main.py		   models
# AE.py			       gan.py			   papers
# AE_trainer.py		       gan_trainer.py		   __pycache__
# checkPoints		       Losses.py		   README.md
# console_AE.ipynb	       MNIST			   spectral.py
# console_gan.ipynb	       MNISTClassifier_main.py	   utils.py
# console_MNISTClassifier.ipynb  MNISTClassifier.py	   visualizer.py
# gan			       MNISTClassifier_trainer.py

# %%
# !python MNISTClassifier_main.py --numEpochs 20 --lr 0.002 --batch_size 1024
# Out:
#   0% 0/59 [00:00<?, ?it/s]/content/drive/My Drive/courses/Generative Adversial Models_CS236g/RLGan_cs236g/MNISTClassifier.py:79: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
#  34% 20/59 [00:05<00:11,  3.52it/s]Step 20: Classifier loss: 0.25808160379529
#  68% 40/59 [00:10<00:04,  3.86it/s]Step 40: Classifier loss: 0.1446579359471798
# 100% 59/59 [00:15<00:00,  3.83it/s]
#   2% 1/59 [00:00<00:14,  3.97it/s]Step 60: Classifier loss: 0.12459496185183525
#  36% 21/59 [00:05<00:10,  3.47it/s]Step 80: Classifier loss: 0.11393854767084122
#  69% 41/59 [00:11<00:04,  3.74it/s]Step 100: Classifier loss: 0.10694359429180622
# 100% 59/59 [00:15<00:00,  3.73it/s]
#   3% 2/59 [00:00<00:15,  3.57it/s]Step 120: Classifier loss: 0.10639599524438381
#  37% 22/59 [00:06<00:10,  3.62it/s]Step 140: Classifier loss: 0.10102366842329502
# ...

# %%
import torch
target = torch.randint(0, 3, (5,))
one_hot = torch.nn.functional.one_hot(target)
print(target)
print(one_hot)
# Out:
# tensor([2, 2, 0, 0, 0])
# tensor([[0, 0, 1],
#         [0, 0, 1],
#         [1, 0, 0],
#         [1, 0, 0],
#         [1, 0, 0]])

# %%
import numpy as np
x = np.linspace(0,10,100)

# %%
z,y = x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ce9d19006336> in <module>()
# ----> 1 z,y = x
#
# ValueError: too many values to unpack (expected 2)

# %%
from VAE_c import VAE
vae = VAE()

# %%
vae.state_dict

# %%
vae.load_state_dict(torch.load(PATH))

# %%
from VAE_train import *

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU

# %%
GPU.getGPUs()

# %%
main('cuda')
