# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/courses/Generative\ Adversial\ Models_CS236g/RLGan_cs236g/
# !ls
# Out:
# /content/drive/My Drive/courses/Generative Adversial Models_CS236g/RLGan_cs236g
# AE_main.py		       gan_main.py		   papers
# AE.py			       gan.py			   __pycache__
# AE_trainer.py		       gan_tester.py		   README.md
# checkPoints		       gan_trainer.py		   RL_main.py
# console_AE.ipynb	       logs			   RL.py
# console_gan.ipynb	       MNIST			   RL_trainer.py
# console_MNISTClassifier.ipynb  MNISTClassifier_main.py	   spectral.py
# console_RL.ipynb	       MNISTClassifier.py	   utils.py
# EnvClass.py		       MNISTClassifier_trainer.py
# gan			       models

# %%
# !python RL_main.py --batch_size 1 --max_action 3  --start_timesteps 10000 # --eval_freq 1000
# Out:
# Using TITAN XP GPU # : 0
# Namespace(activation='relu', attempts=5, batch_size=1, batch_size_actor=10, d_conv_dim=16, data='', dataIncompLarge='', dataIncomplete='', device=device(type='cuda', index=0), discount=0.99, display_id=1001, display_winsize=256, env_name='RLGAN', eval_freq=5000.0, expl_noise=0.1, feature_num=1024, g_conv_dim=16, gpu_id=0, image_size=32, l_size=32, max_action=3, max_episodes_steps=5, max_timesteps=1000000.0, model_decoder='decoder_sonet', model_discriminator='self_disc_net', model_encoder='encoder_pointnet', model_generator='self_gen_net', name='train', net_name='auto_encoder', noise_clip=0.5, normalization='batch', output_conv_pc_num=4096, output_fc_pc_num=256, policy_freq=2, policy_name='DDPG', policy_noise=0.2, port_id=8102, pretrained_Actor='/home/ymkim/ShapeCompletion/pointShapeComplete/pytorch_models/DDPG_RLGAN_actor.pth', pretrained_Critic='/home/ymkim/ShapeCompletion/pointShapeComplete/pytorch_models/DDPG_RLGAN_critic.pth', pretrained_D='/media/sarmad/hulk/self attention GAN backup/models/sagan_celeb_1dim/999810_D.pth', pretrained_G='/media/sarmad/hulk/self attention GAN backup/models/sagan_celeb_1dim/999810_G.pth', pretrained_enc_dec='/home/sarmad/PycharmProjects/pointShapeComplete/ckpts/shapenet/09-04-21:05/ae_pointnet,Adam,1000epochs,b50,lr0.0005/model_best.pth.tar', print_freq=40, save=True, save_models=True, save_path='./checkPoints', split_value=0.9, start_timesteps=10000, state_dim=32, tau=0.005, test_only=False, train=True, weight=10, workers=8, z_dim=2)
# Encoder Model: encoder_pointnet, Decoder Model : decoder_sonet
# GAN Model Generator:self_gen_net & Discriminator : self_disc_net
# | Number of Encoder parameters [25008]...
# | Number of Decoder parameters [674113]...
# /content/drive/My Drive/courses/Generative Adversial Models_CS236g/RLGan_cs236g/MNISTClassifier.py:47: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# ---------------------------------------
# Evaluation over 6 episodes: 8.509090
# ---------------------------------------
# 1000/1000000.0
# 2000/1000000.0
# 3000/1000000.0
# 4000/1000000.0
# 5000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 4.597103
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# /content/drive/My Drive/courses/Generative Adversial Models_CS236g/RLGan_cs236g/MNISTClassifier.py:47: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 3.822314
# ---------------------------------------
# 6000/1000000.0
# 7000/1000000.0
# 8000/1000000.0
# 9000/1000000.0
# 10000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: -1.334443
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 5.716425
# ---------------------------------------
# 11000/1000000.0
# 12000/1000000.0
# 13000/1000000.0
# 14000/1000000.0
# 15000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.859838
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes:
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 19.639035
# ---------------------------------------
# 241000/1000000.0
# 242000/1000000.0
# 243000/1000000.0
# 244000/1000000.0
# 245000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 23.293304
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 25.242625
# ---------------------------------------
# 246000/1000000.0
# 247000/1000000.0
# 248000/1000000.0
# 249000/1000000.0
# 250000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 10.454452
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 24.254446
# ---------------------------------------
# 251000/1000000.0
# 252000/1000000.0
# 253000/1000000.0
# 254000/1000000.0
# 255000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 21.556086
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 20.505116
# ---------------------------------------
# 256000/1000000.0
# 257000/1000000.0
# 258000/1000000.0
# 259000/1000000.0
# 260000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 21.208518
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 23.646032
# ---------------------------------------
# 261000/1000000.0
# 262000/1000000.0
# 263000/1000000.0
# 264000/1000000.0
# 265000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 23.275009
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 18.818877
# ---------------------------------------
# 266000/1000000.0
# 267000/1000000.0
# 268000/1000000.0
# 269000/1000000.0
# 270000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 19.985886
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 20.673275
# ---------------------------------------
# 271000/1000000.0
# 272000/1000000.0
# 273000/1000000.0
# 274000/1000000.0
# 275000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 21.768541
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 20.357017
# ---------------------------------------
# 276000/1000000.0
# 277000/1000000.0
# 278000/1000000.0
# 279000/1000000.0
# 280000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 26.218726
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 26.325333
# ---------------------------------------
# 281000/1000000.0
# 282000/1000000.0
# 283000/1000000.0
# 284000/1000000.0
# 285000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 22.313020
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 20.203767
# ---------------------------------------
# 286000/1000000.0
# 287000/1000000.0
# 288000/1000000.0
# 289000/1000000.0
# 290000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 17.417737
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 21.895732
# ---------------------------------------
# 291000/1000000.0
# 292000/1000000.0
# 293000/1000000.0
# 294000/1000000.0
# 295000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 20.606807
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 24.463388
# ---------------------------------------
# 296000/1000000.0
# 297000/1000000.0
# 298000/1000000.0
# 299000/1000000.0
# 300000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 23.257233
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 18.693423
# ---------------------------------------
# 301000/1000000.0
# 302000/1000000.0
# 303000/1000000.0
# 304000/1000000.0
# 305000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 20.394883
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 17.556242
# ---------------------------------------
# 306000/1000000.0
# 307000/1000000.0
# 308000/1000000.0
# 309000/1000000.0
# 310000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 23.457738
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 15.296830
# ---------------------------------------
# 311000/1000000.0
# 312000/1000000.0
# 313000/1000000.0
# 314000/1000000.0
# 315000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 22.181194
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 20.015169
# ---------------------------------------
# 316000/1000000.0
# 317000/1000000.0
# 318000/1000000.0
# 319000/1000000.0
# 320000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 20.503490
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 21.365889
# ---------------------------------------
# 321000/1000000.0
# 322000/1000000.0
# 323000/1000000.0
# 324000/1000000.0
# 325000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 13.983733
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 20.243711
# ---------------------------------------
# 326000/1000000.0
# 327000/1000000.0
# 328000/1000000.0
# 329000/1000000.0
# 330000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 16.820181
# ---------------------------------------
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# <Figure size 500x500 with 1 Axes>
# ---------------------------------------
# Evaluation over 12 episodes: 22.038034
# ---------------------------------------
# 331000/1000000.0
# 332000/1000000.0
# 333000/1000000.0

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

z=torch.tensor([[1,2,3]])
# map = np.array([[1,1,2]])
# print(z[0:1:z.shape[0],[2,1,0]])

# %%
hinge = torch.nn.HingeEmbeddingLoss()

# %%
x = torch.linspace(-10,10,1000)
y = torch.ones_like(x)
for i in range(1000):
  y[i] =hinge(x[i],torch.tensor(-1))

plt.plot(x,y)

# %%
z.unsqueeze(0)

# %%
np.round_(0.12345, decimals = 3)
