# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/courses/Generative\ Adversial\ Models_CS236g/RLGan_cs236g/
# !ls
# Out:
# /content/drive/My Drive/courses/Generative Adversial Models_CS236g/RLGan_cs236g
# AE_main.py		       gan_main.py		   papers
# AE.py			       gan.py			   __pycache__
# AE_trainer.py		       gan_tester.py		   README.md
# checkPoints		       gan_trainer.py		   RL_main.py
# console_AE.ipynb	       logs			   RL.py
# console_envTest.ipynb	       MNIST			   RL_trainer.py
# console_gan.ipynb	       MNISTClassifier_main.py	   spectral.py
# console_MNISTClassifier.ipynb  MNISTClassifier.py	   utils.py
# EnvClass.py		       MNISTClassifier_trainer.py
# gan			       models

# %%
# !python RL_main.py --batch_size 1
# Out:
# Using TITAN XP GPU # : 0
# Namespace(activation='relu', attempts=5, batch_size=1, batch_size_actor=100, d_conv_dim=16, data='', dataIncompLarge='', dataIncomplete='', device=device(type='cuda', index=0), discount=0.99, display_id=1001, display_winsize=256, env_name='RLGAN', eval_freq=5000.0, expl_noise=0.1, feature_num=1024, g_conv_dim=16, gpu_id=0, image_size=32, l_size=32, max_action=10, max_episodes_steps=5, max_timesteps=1000000.0, model_decoder='decoder_sonet', model_discriminator='self_disc_net', model_encoder='encoder_pointnet', model_generator='self_gen_net', name='train', net_name='auto_encoder', noise_clip=0.5, normalization='batch', output_conv_pc_num=4096, output_fc_pc_num=256, policy_freq=2, policy_name='DDPG', policy_noise=0.2, port_id=8102, pretrained_Actor='/home/ymkim/ShapeCompletion/pointShapeComplete/pytorch_models/DDPG_RLGAN_actor.pth', pretrained_Critic='/home/ymkim/ShapeCompletion/pointShapeComplete/pytorch_models/DDPG_RLGAN_critic.pth', pretrained_D='/media/sarmad/hulk/self attention GAN backup/models/sagan_celeb_1dim/999810_D.pth', pretrained_G='/media/sarmad/hulk/self attention GAN backup/models/sagan_celeb_1dim/999810_G.pth', pretrained_enc_dec='/home/sarmad/PycharmProjects/pointShapeComplete/ckpts/shapenet/09-04-21:05/ae_pointnet,Adam,1000epochs,b50,lr0.0005/model_best.pth.tar', print_freq=40, save=True, save_models=True, save_path='./RL_ckpt', split_value=0.9, start_timesteps=10000.0, state_dim=32, tau=0.005, test_only=False, train=True, weight=10, workers=8, z_dim=2)
# Encoder Model: encoder_pointnet, Decoder Model : decoder_sonet
# GAN Model Generator:self_gen_net & Discriminator : self_disc_net
# | Number of Encoder parameters [25008]...
# | Number of Decoder parameters [674113]...
# /content/drive/My Drive/courses/Generative Adversial Models_CS236g/RLGan_cs236g/MNISTClassifier.py:47: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# ---------------------------------------
# Evaluation over 6 episodes: 0.836707
# ---------------------------------------
# 1000/1000000.0
# 2000/1000000.0
# 3000/1000000.0
# 4000/1000000.0
# 5000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.770124
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.799717
# ---------------------------------------
# 6000/1000000.0
# 7000/1000000.0
# 8000/1000000.0
# 9000/1000000.0
# 10000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.000440
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.023443
# ---------------------------------------
# 11000/1000000.0
# 12000/1000000.0
# 13000/1000000.0
# 14000/1000000.0
# 15000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.045097
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.000440
# ---------------------------------------
# 16000/1000000.0
# 17000/1000000.0
# 18000/1000000.0
# 19000/1000000.0
# 20000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 8.007824
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.267425
# ---------------------------------------
# 21000/1000000.0
# 22000/1000000.0
# 23000/1000000.0
# 24000/1000000.0
# 25000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 8.007673
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.213082
# ---------------------------------------
# 26000/1000000.0
# 27000/1000000.0
# 28000/1000000.0
# 29000/1000000.0
# 30000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.053992
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.237295
# ---------------------------------------
# 31000/1000000.0
# 32000/1000000.0
# 33000/1000000.0
# 34000/1000000.0
# 35000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.038098
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.213059
# ---------------------------------------
# 166000/1000000.0
# 167000/1000000.0
# 168000/1000000.0
# 169000/1000000.0
# 170000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.267502
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 8.007333
# ---------------------------------------
# 171000/1000000.0
# 172000/1000000.0
# 173000/1000000.0
# 174000/1000000.0
# 175000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 8.007603
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.745295
# ---------------------------------------
# 176000/1000000.0
# 177000/1000000.0
# 178000/1000000.0
# 179000/1000000.0
# 180000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.038094
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 8.007485
# ---------------------------------------
# 181000/1000000.0
# 182000/1000000.0
# 183000/1000000.0
# 184000/1000000.0
# 185000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.237242
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 8.007413
# ---------------------------------------
# 186000/1000000.0
# 187000/1000000.0
# 188000/1000000.0
# 189000/1000000.0
# 190000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.141421
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.267458
# ---------------------------------------
# 191000/1000000.0
# 192000/1000000.0
# 193000/1000000.0
# 194000/1000000.0
# 195000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.237236
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.237325
# ---------------------------------------
# 196000/1000000.0
# 197000/1000000.0
# 198000/1000000.0
# 199000/1000000.0
# 200000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.292262
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.213062
# ---------------------------------------
# 201000/1000000.0
# 202000/1000000.0
# 203000/1000000.0
# 204000/1000000.0
# 205000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 8.007851
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.237294
# ---------------------------------------
# 206000/1000000.0
# 207000/1000000.0
# 208000/1000000.0
# 209000/1000000.0
# 210000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.038101
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.141382
# ---------------------------------------
# 211000/1000000.0
# 212000/1000000.0
# 213000/1000000.0
# 214000/1000000.0
# 215000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.213064
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.053999
# ---------------------------------------
# 216000/1000000.0
# 217000/1000000.0
# 218000/1000000.0
# 219000/1000000.0
# 220000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.267438
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.038107
# ---------------------------------------
# 221000/1000000.0
# 222000/1000000.0
# 223000/1000000.0
# 224000/1000000.0
# 225000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.213086
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.141361
# ---------------------------------------
# 226000/1000000.0
# 227000/1000000.0
# 228000/1000000.0
# 229000/1000000.0
# 230000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.267577
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.292248
# ---------------------------------------
# 231000/1000000.0
# 232000/1000000.0
# 233000/1000000.0
# 234000/1000000.0
# 235000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.237293
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.053991
# ---------------------------------------
# 236000/1000000.0
# 237000/1000000.0
# 238000/1000000.0
# 239000/1000000.0
# 240000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.267435
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 8.007560
# ---------------------------------------
# 241000/1000000.0
# 242000/1000000.0
# 243000/1000000.0
# 244000/1000000.0
# 245000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.237269
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.292291
# ---------------------------------------
# 246000/1000000.0
# 247000/1000000.0
# 248000/1000000.0
# 249000/1000000.0
# 250000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.213062
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.237298
# ---------------------------------------
# 251000/1000000.0
# 252000/1000000.0
# 253000/1000000.0
# 254000/1000000.0
# 255000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.267396
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.267563
# ---------------------------------------
# 256000/1000000.0
# 257000/1000000.0
# 258000/1000000.0
# 259000/1000000.0
# 260000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.053993
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 8.007473
# ---------------------------------------
# 261000/1000000.0
# 262000/1000000.0
# 263000/1000000.0
# 264000/1000000.0
# 265000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.237227
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.237291
# ---------------------------------------
# 266000/1000000.0
# 267000/1000000.0
# 268000/1000000.0
# 269000/1000000.0
# 270000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.267477
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.292289
# ---------------------------------------
# 271000/1000000.0
# 272000/1000000.0
# 273000/1000000.0
# 274000/1000000.0
# 275000/1000000.0
# ---------------------------------------
# Evaluation over 6 episodes: 0.237319
# ---------------------------------------
# ---------------------------------------
# Evaluation over 12 episodes: 0.267450
# ---------------------------------------
# 276000/1000000.0
# 277000/1000000.0
# 278000/1000000.0

# %%
import numpy as np
import torch
z=torch.tensor([[1,2,3]])
# map = np.array([[1,1,2]])
# print(z[0:1:z.shape[0],[2,1,0]])

# %%
x = z.reshape(tuple(z.shape)+(1,1))

# %%
x.shape
# Out:
# torch.Size([1, 3, 1, 1])

# %%
z.unsqueeze(0)
# Out:
# tensor([[[1, 2, 3]]])
